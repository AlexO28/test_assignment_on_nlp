# %%
import pandas as pd

# %%
tab = pd.read_csv('file.csv', sep=';')
tab.reset_index(inplace=True)

# %% [markdown]
# # Обработка данных.

# %%
from lemmatization import prepare_lemmatized_text, remove_punctuation

# %%
tab['text_employer'] = remove_punctuation(tab)

# %%
tab['text'] = tab['text_employer'].apply(lambda x: prepare_lemmatized_text(x))

# %%
from stop_words import get_stop_words

# %%
stop_words = get_stop_words('ru')

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(stop_words=stop_words)

# %% [markdown]
# # Запуск LDA.

# %%
data_for_lda = cv.fit_transform(tab['text'])

# %%
from sklearn.decomposition import LatentDirichletAllocation as LDA

# %%
model = LDA(n_components=50, random_state=239)

# %%
model.fit(data_for_lda)
# Out:
# LatentDirichletAllocation(n_components=50, random_state=239)

# %%
import numpy as np

# %%
def get_keywords(text, cv, model, n_topics=3, n_keywords=5):
    vectorized = cv.transform([text])
    lda_topics = model.transform(vectorized)
    lda_topics = np.squeeze(lda_topics, axis=0)
    n_topics_indices = lda_topics.argsort()[-n_topics:][::-1]

    top_topics_words_dists = []
    for i in n_topics_indices:
        top_topics_words_dists.append(model.components_[i])

    shape=(n_keywords*n_topics, model.components_.shape[1])
    keywords = np.zeros(shape=shape)
    for i, topic in enumerate(top_topics_words_dists):
        n_keywords_indices = topic.argsort()[-n_keywords:][::-1]
        for k, j in enumerate(n_keywords_indices):
            keywords[i * n_keywords + k, j] = 1
    keywords = cv.inverse_transform(keywords)
    keywords = [keyword[0] for keyword in keywords]
    return keywords

# %% [markdown]
# Мы берём первую тему и 3 ключевых слова, ей соответствующие в каждом случае.
#
# Первая тема самая важная, одного слова может быть недостаточно.

# %%
res = []

for text in tab['text']:
    res.append(get_keywords(text, cv, model, 1, 3))

# %%
long_string = ' '.join([x[0] + ' ' +  x[1] + ' ' + x[2] for x in res])

# %%
topics = list(set(long_string.split(' ')))

# %%
len(topics)
# Out:
# 97

# %%
topics
# Out:
# ['ограничение',
#  'физический_лицо',
#  'эквайринг',
#  'клиент',
#  'терминал',
#  'уточнить',
#  'расчетный',
#  'карта',
#  'кабинет',
#  'никак',
#  'крестьянский',
#  'извините',
#  'пароль',
#  'переводить',
#  'банк',
#  'надежда',
#  'провести',
#  'оператор',
#  'город',
#  'перевод',
#  'наличные',
#  'направить',
#  'торговый_эквайринг',
#  'изменение',
#  'номер',
#  'организация',
#  'заявка',
#  'сотрудник',
#  'подпись',
#  'поэтому',
#  'лимит',
#  'нужный',
#  'информация',
#  'оборот',
#  'удобный',
#  'сообщение',
#  'закрыть',
#  'кредит',
#  'планировать',
#  'здравствуйте',
#  'коллега',
#  'электронный',
#  'услуга',
#  'мобильный',
#  'выбрать',
#  'оплата',
#  'хозяйство',
#  'решение',
#  'навигация',
#  'просить',
#  'смс',
#  'отделение_банк',
#  'подсказать',
#  'акция',
#  'выплата',
#  'специалист',
#  'понять',
#  'подойти',
#  'сын',
#  'зарплатный_проект',
#  'отделение',
#  'добрый_день',
#  'ноль',
#  'торговый',
#  'вопрос',
#  'приложить',
#  'доставка',
#  'прямой',
#  'перезвонить',
#  'покупка',
#  'рубль',
#  'бизнес',
#  'линия',
#  'сайт',
#  'индивидуальный',
#  'офис_банка',
#  'пакет_услуга',
#  'код',
#  'слышать',
#  'точка',
#  'месяц',
#  'повод',
#  'контакт',
#  'деятельность',
#  'платеж',
#  'прощение',
#  'звонить',
#  'заинтересованность',
#  'адрес',
#  'офис',
#  'кредитование',
#  'комиссия',
#  'поддержка',
#  'попробовать',
#  'счет',
#  'поговорить',
#  'логин']

# %% [markdown]
# Нужных нам тем немного. Проще всего сделать ручную разметку (см. Excel файл).

# %% [markdown]
# # Создание тем на основе ручной разметки.

# %%
direct_dict = {}

# %%
direct_dict["Приветствие"] = ["здравствуйте", "добрый_день"]

# %%
direct_dict["Перенос активности"] = ['оператор', 'поддержка', 'контакт', 'специалист', 'подойти', 'переводить', 'попробовать', 'коллега',
'отделение_банк', 'офис', 'звонить', 'линия', 'информация', 'сотрудник', 'отделение', 'направить', 'подсказать', 'поговорить', 'уточнить', 'адрес', 'банк', 'сайт', 'офис_банка', 'терминал']

# %%
direct_dict["Окончание разговора"] = ['прощение', 'просить', 'извините', 'перезвонить', 'никак']

# %%
direct_dict["Болтовня"] = ['надежда', 'ноль', 'сын', 'крестьянский', 'хозяйство', 'точка']

# %%
direct_dict["Следующие шаги"] = ['поэтому', 'провести', 'планировать', 'повод', 'приложить']

# %%
direct_dict["Безопасность"] = ['пароль', 'смс', 'логин', 'код', 'сообщение', 'подпись', 'лимит']

# %%
direct_dict["Тарифы или Цены"] = ['рубль', 'пакет_услуга']

# %%
direct_dict["Акции"] = ['услуга', 'комиссия', 'зарплатный_проект', 'индивидуальный', 'акция']

# %%
direct_dict["Удобство работы"] = ['удобный', 'доставка', 'кабинет', 'ограничение', 'электронный', 'мобильный']

# %%
direct_dict["Простота настройки"] = ["понять", "навигация", "нужный"]

# %%
direct_dict["Скорость работы"] = ["прямой"]

# %%
direct_dict["Преимущества"] = ['выбрать', 'закрыть', 'месяц', 'кредитование', 'кредит', 'заявка', 'бизнес']

# %%
direct_dict["Вовлечение или подведение к диалогу"] = ['наличные', 'платеж', 'клиент', 'деятельность', 'заинтересованность', 'физический_лицо', 'слышать', 'счет', 'организация']

# %%
direct_dict["Призыв к действию"] = ['решение', 'изменение', 'покупка', 'номер', 'оплата', 'перевод', 'город', 'расчетный', 'выплата', 'оборот']

# %%
direct_dict["Инструкция по подключению или приобретению"] = ["карта", "торговый_эквайринг", "эквайринг", "торговый"]

# %%
direct_dict["Вопрос клиента"] = ["вопрос"]

# %%
inversed_dict = {}
for key in direct_dict.keys():
    for value in direct_dict[key]:
        inversed_dict[value] = key

# %%
tab['topics'] = ""

# %%
for j in range(len(res)):
    words = res[j]
    analogs = list(set([inversed_dict[word] for word in words]))
    tab.loc[j, "topics"] = " ".join(analogs)

# %%
for key in direct_dict.keys():
    print(key)
    tabred = tab[tab['topics'].str.contains(key)]
    print(len(tabred))
# Out:
# Приветствие
# 69
# Перенос активности
# 3476
# Окончание разговора
# 1564
# Болтовня
# 146
# Следующие шаги
# 60
# Безопасность
# 686
# Тарифы или Цены
# 191
# Акции
# 1404
# Удобство работы
# 1446
# Простота настройки
# 193
# Скорость работы
# 6
# Преимущества
# 1438
# Вовлечение или подведение к диалогу
# 739
# Призыв к действию
# 1490
# Инструкция по подключению или приобретению
# 1556
# Вопрос клиента
# 933

# %%
for key in direct_dict.keys():
    print(key)
    tabred = tab[tab['topics'].str.contains(key)]
    print(tabred['text'].tolist()[0])
# Out:
# Приветствие
# добрый_день
# Перенос активности
# добрый_деть  это ваш персональный_менеджер_сбербанк бизнес звонить вы как индивидуальный_предприниматель вы удобный сейчас говорить  когда когда
# Окончание разговора
# добрый_деть  это ваш персональный_менеджер_сбербанк бизнес звонить вы как индивидуальный_предприниматель вы удобный сейчас говорить  когда когда
# Болтовня
# у я один один
# Следующие шаги
# выходной положить
# Безопасность
# добрый_день максим это персональный_менеджер_сбербанк блок сбер пизда звонить вы как индивидуальный_предприниматель вы удобный говорить  услуга который сбер бизнес рекомендовать для вы хотеть они рассказать чтобы ноль свой возможность  для вы сейчас доступный специальный предложение по бизнес карта карта позволять круглосуточно вносить снимать наличные с расчетный счет основный преимущество оплата ежедневный покупка снятие наличные плата комиссия_банк и фактически карта привязать к ваш расчетный_счет круглосуточный доступ и возможность подключить бизнес кэшбэк  просто сейчас вот как раз для вы действовать специальный предложение если вы  показать карта до по первый март и забрать из отделение по апрель тот год обслуживание по она быть для вы бесплатный  за обслуживание вы не быть платить за обслуживание  заплатить карта тот быть так она стоимость тысяча рубль в мой коллега сказать  а сейчас до вы она быть на год бесплатный тот быть как вот быть вы моментальный карта только она вы на год выдаваться как тот здравствовать  это тоже самый быть только на год с бесплатный обслуживание и она уже именной  просто сейчас специальный предложение  вы на какой система налогообложение находиться  минута сейчас вы сказать так сейчас уточнить информация а так э лимит выдача наличные денежный_средство по бизнес карта тысяча рубль в сутки по каждый карта не более миллион рубль в течение календарный месяц э по расчетный_счет предприятие комиссия за снятие наличные зависеть от выбрать условие обслуживание расчетный счет по с она быть снимать у вы быть браться комиссия тот быть она основный преимущество именно оплата по безналичный расчет  знать минута сейчас вы сказать  я понять вы оставаться пожалуйста на линия хорошо  спасибо  попасться на линия максим уточнить информация вот  учет расход по бизнес карта можно везти так же как и в случай любой другой расход если у вы э на процент патент или енвд система налогообложение мочь пользоваться бизнес с карта как обычно банковский карта если ваш компания для учет налог использовать традиционный система с мтс или процент тот необходимый собирать весь пакет документ накладный чек и так далее  что вы мочь учить расход  по ваш система налоговый а налогообложение вы мочь пользоваться бизнес с карта как обычно банковский карта  это только извинить что перебить  нет просто если вы на патент тот можно вот у мы прям указать информация тот что вы мочь пользоваться бизнес карта как обычно банковский карта_физический_лицо а если бы у вы быть ваш компания для учет налог использовать б система с мтс или у сын процент  тот тогда необходимый быть собирать весь пакет документ что вы мочь учесть расход по бизнес карта перерасчет налог  более подробный информация о учет расход по бизнес карта вы мочь посмотреть в памятка для  если вы интересный мочь с вы заказать в режим диалог  год  если  она весь равный на год выдаваться у вы как раз на год она быть  потом если вы заинтересовать в дальнейший вы уже мочь она заказать но у вы уже быть она стоимость тысяча рубль в год  единственный вы мочь здесь платно подключить смс информирование штоб вы весь информация приходить она стоить рубль в месяц но вы мочь она не подключаться это тоже на ваш усмотрение  мы мочь с вы сейчас в режим диалог заказать в сбербанк_бизнес_онлайн быть возможность зайти в личный_кабинет  через компьютер только  и вот стандартный срок доставка карта в отделение а до рабочий день ну срок мочь быть увеличить в зависимость от доступность населить пункт вы получить смс о готовность карта самостоятельно уточнить готовность карта можно по телефон пятерка семерка добавочно затем и когда быть заказывать карта мы с вы сейчас а если смочь зайти в личный_кабинет там быть у вы указать стоимость рубль либо тысяча рубль на это не обращать внимание главное вы нужный быть забрать карта по апрель если вы например поздний забрать  до рабочий день  именной  вы иметь в вид по бизнес карта  вот указать можно оплачивать покупка для оплата в интернет вы понадобиться номер карта ...
# Тарифы или Цены
# добрый_деть  я звать персональный_менеджер_сбербанк блок сбер бизнес звонить вы как индивидуальный_предприниматель удобный сейчас говорить  не заем много ваш время быть вопрос который хотеться бы уточнить вы я неактивна стать пользоваться зарплатный_проект в сбербанк сказать пожалуйста с что это связать  э текущий ситуация в страна  я вы понять возможно у вы быть какой тот вопрос по использование сервис  я вы слушать  вы мочь пополнить свой расчетный счет  как раз у я для вы быть предложение это мочь быть слышать бизнес карта у мы быть бизнес карта являться фактически физический носитель ваш расчетный счет вы помимо тот что мочь вносить по она деньга на расчетный счет снимать с он деньга  также вы мочь напрямую расплачиваться этот карта и когда напрямую расплачиваться а тот у вы естественно никакой комиссия ничто нет соответственно вы не нужный быть дополнительный действие делать по перевод сначала на свой расчетный счет сначала на карта_физический_лицо а потом уже она расплачиваться и плюс к весь по бизнес карта быть еще и кэшбэк тот быть за каждый покупка вы начисляться целый процент бонусный балл от до тысяча бонус называть вы уже мочь конвертировать себя в рубль на расчетный счет сейчас у мы так же быть возможность оформить виртуальный карта  это не требовать посещение офис она сразу доступный для использование ваш смартфон и у она стоимость ниже тот быть если говорить о обычный бизнес карта там идти тысяча рубль стоимость в год а здесь э рубль в год либо вариант помесячно плата можно выбрать рубль какой вариант для вы быть бы удобнее  тысяча рубль в год либо вариант например помесячно оплата рубль в месяц  вы как раз мочь выпустить например выбрать помесячно оплата посмотреть на сколько вы удобный пользоваться карта  что скажете я мочь помочь вы с оформление  если хотеть мочь направить вы на почта информация чтобы вы еще раз ознакомиться  там быть помимо описание сам продукт бизнес карта ссылка на сайт в раздел банк в раздел помощь там быть все вопрос интересовать по бизнес карта тот быть как вносить э как это все быть отображаться у вы в учет большой изучить продукт и я вы мочь перезвонить потом узнать ваш решение мочь быть у вы также быть вопрос  указать на почта  точно  я мочь на она направить  хорошо а когда вы быть бы удобный чтобы я вы перезвонить если  например в суббота быть удобный или на следующий неделя например  а  я тогда информация вы направить свой контакт направиться с номер  если быть так же какой тот вопрос звонить мы большинство услуга дистанционно подключать  мы направлять вы смс сообщение если говорить о звонок именно ma
# ager который связать с работа с юридический_лицо на сайт банк в раздел малый бизнес и если ставить вниз  там быть контакт по по номер_телефон по который мочь звонит сотрудник банк тот быть на сайт быть информация быть список номер с который мы звонить соответственно вы мочь проверить  всего добрый тогда до свидание  вот у вы связаться с банк быть сам низ все на сайт здесь вот быть указать наш телефон это один  и вот этот телефон обычный свой совершать звонок это если говориться линия для юридический_лицо лицо мочь так же там в раздел банк на сайт зайти по работа именно уже юридический_лицо там быть тоже указать телефон  все всего добрый тогда до свидание хороший день
# Акции
# добрый_день строка  это клиентский_менеджер_сбербанк блок сбер бизнес я звонить вы как индивидуальный_предприниматель он вы удобный говорить  я звонить у вы уточнить минута ваш время как раз э вы не пользоваться зарплатный_проект сбербанк а сказать пожалуйста с что тот связать  в декабрь  хорошо я понять  я понять значит когда только обороты пойти сразу быть пользоваться зарплатный_проект  а по код воспользоваться весь в порядок правильно быть  весь верный до тысяча календарный месяц без комиссия  только хорошо я вы понять по зарплатный_проект информация отмечу и вот э хотеть еще уточнить для вы быть лимит по кредитование вы быть бы интересный рассмотреть  весь хорошо отлично понять вы сейчас сейчас вопрос нет у вы  а  контакт у вы быть если какой тот вопрос быть возникать либо потребоваться оформить услуга сбер звонить большинство из они подключать дистанционно экономить ваш время быть рад помочь вы  весь добрый вы до свидание
# Удобство работы
# добрый_деть  это ваш персональный_менеджер_сбербанк бизнес звонить вы как индивидуальный_предприниматель вы удобный сейчас говорить  когда когда
# Простота настройки
# по это персональный_менеджер я звонить по организация серебряниковский мрамор а с кто я мочь поговорить кто принимать решение  по организация  но решение не принимать тот быть по продукт_банк  а я мочь перезвонить на какой контактный телефон у я указать еще один мочь быть знать это актуальный номер или нет  ну я тогда после март перезвоню спасибо большой что сориентировать  хорошо пускай отдыхать не быть отвлекать перезвоню в март спасибо большой  всего добрый до свидание
# Скорость работы
# выходной положить
# Преимущества
# добрый_деть  это ваш персональный_менеджер сбер бизнес звонить вы как индивидуальный_предприниматель вы удобный говорить сейчас  не занять у вы много время звонить рассказать что для вы доступный специальный предложение по бизнес карта этот карта позволять круглосуточно вносить и снимать наличные с расчетный счет основный она преимущество это оплата ежедневный покупка снятие наличные она плата комиссия_банк фактически этот карта привязать к ваш расчетный_счет с круглосуточный доступ и возможность подключить бизнес кэшбэк чтобы зарабатывать на свой покупка если вы забрать карта с отделение а до апрель включительно год обслуживание по она быть для вы бесплатный подать заявка при это необходимый э по первый март включительно оформить для вы такой карта  мочь уточнить а что именно не подойти предложение мы важный обратный связь получить от свой клиент  мочь уточнить что тот не подходить возможный обслуживание  расчетный счет по какой причина хотеть закрыть  я вы понять до этот информация отмечу  в любой случай бизнес_карта этот карта к расчетный_счет привязать для вы  я вы понять этот информация отмечу хотеть предложить для ваш лишь удобство разделить использование личный средство и затрата в рамка бизнес вы мочь оплачивать расход на бизнес с помощь бизнес_карта наличный карта переводить свой доход  а сейчас для вы она бесплатный  акция  я вы понять этот информация отметить возможно к я вопрос у вы я сейчас я мочь бы  в такой случай свой контакт отправить смс сообщение если вопрос возникнуть мочь перезвонить большинство услуга подключать дистанционно  сэкономить ваш время быть рад помочь спасибо большой за уделить время весь добрый хороший день вы до свидание
# Вовлечение или подведение к диалогу
# добрый_день  надежда сбербанк блок сбер бизнес о он как индивидуальный_предприниматель удобный сейчас говорить  осуществляю сервисный звонок у вы установить торговый половинка от сбербанк а за последний время через терминал сбербанк вы проводить в основный только карта_сбербанк а сказать пожалуйста  вы устраивать я не требоваться дополнительный оборот не мочь быть пользоваться еще оборот другой банк для прием  карта_физический_лицо  сказать пожалуйста а дополнительно наоборот не ваш торговый точка не требоваться весь в порядок  если в будущее а вы понадобиться помощь установка дополнительный терминал или услуга оплата потереть подать звонить я я мочь это сделать сказать пожалуйста а  а вы вот ранее быть заинтересовать в услуга оплата по код на сегодня момент э пользоваться  хотеть воспользоваться услуга  я вы понять а сказать к я мочь быть есть какой тот вопрос по другой продукт  контактный данные вы продублировать для обратный связь если в будущее вы возникнуть вопрос по оформление продукт услуга_банк пожалуйста обращаться я ставить услуга мы оформлять дистанционно ваш время я вы помочь  хороший день весь добрый до свидание
# Призыв к действию
# здравствовать  это ваш персональный_менеджер и вы теперь бизнес я звонить как индивидуальный_предприниматель вы удобный сейчас говорить  удалить пожалуйста минута ваш время быть предложение который хотеться бы обсудить последний время вы практически полностью перестать пользоваться терминал сбербанк по эквайринг сказать пожалуйста а с что это мочь быть связать  тот быть у вы весь устраивать не устраивать просто пока не сезон  я вы понять в данный случай у вы по эквайринг быть какой либо вопрос готовый на они ответить  я вы я вы понять так же еще один вопрос интересовать  сказать вы работать один или быть сотрудник также в штат  какой образ вы выплачивать себя заработный_плата наличный или перевод на карта  наличные в этот случай я рекомендовать вы подключить э зарплатный_проект вы сможете выплачивать а  себя дело в тот тот что а личный_карта сбербанк мочь подключить зарплатный_договор и до тысяча в месяц без комиссия сможете переводить это дополнительно к тот сумма который я с расчетный счет можно на карта юридический_лицо переводить без комиссия обратите внимание что раздел такой перевод можно выбор код означать он перевод средство идеально предприниматель наличный счет зачисление происходить быстро плюс оплата за обслуживание классический карта полностью отменяться если золотой тот снижаться на процент подключить она очень легко в офис зайти не нужный можно прям сейчас если условие вы подходить  я вы понять сказать пожалуйста а мочь что тот еще вы не подходить мы важный мнение клиент  в такой случай если у вы быть какой либо еще вопрос мочь так же они отдать  понять сейчас я тогда свой контактный данные с номер прислать если он потребоваться конечно оформить услуга сбер звонить я большинство возникнуть дистанционный ваш время быть рад помочь вы  весь добрый
# Инструкция по подключению или приобретению
# добрый_деть  это ваш персональный_менеджер сбер бизнес звонить вы как индивидуальный_предприниматель вы удобный говорить сейчас  не занять у вы много время звонить рассказать что для вы доступный специальный предложение по бизнес карта этот карта позволять круглосуточно вносить и снимать наличные с расчетный счет основный она преимущество это оплата ежедневный покупка снятие наличные она плата комиссия_банк фактически этот карта привязать к ваш расчетный_счет с круглосуточный доступ и возможность подключить бизнес кэшбэк чтобы зарабатывать на свой покупка если вы забрать карта с отделение а до апрель включительно год обслуживание по она быть для вы бесплатный подать заявка при это необходимый э по первый март включительно оформить для вы такой карта  мочь уточнить а что именно не подойти предложение мы важный обратный связь получить от свой клиент  мочь уточнить что тот не подходить возможный обслуживание  расчетный счет по какой причина хотеть закрыть  я вы понять до этот информация отмечу  в любой случай бизнес_карта этот карта к расчетный_счет привязать для вы  я вы понять этот информация отмечу хотеть предложить для ваш лишь удобство разделить использование личный средство и затрата в рамка бизнес вы мочь оплачивать расход на бизнес с помощь бизнес_карта наличный карта переводить свой доход  а сейчас для вы она бесплатный  акция  я вы понять этот информация отметить возможно к я вопрос у вы я сейчас я мочь бы  в такой случай свой контакт отправить смс сообщение если вопрос возникнуть мочь перезвонить большинство услуга подключать дистанционно  сэкономить ваш время быть рад помочь спасибо большой за уделить время весь добрый хороший день вы до свидание
# Вопрос клиента
# добрый_день строка  это клиентский_менеджер_сбербанк блок сбер бизнес я звонить вы как индивидуальный_предприниматель он вы удобный говорить  я звонить у вы уточнить минута ваш время как раз э вы не пользоваться зарплатный_проект сбербанк а сказать пожалуйста с что тот связать  в декабрь  хорошо я понять  я понять значит когда только обороты пойти сразу быть пользоваться зарплатный_проект  а по код воспользоваться весь в порядок правильно быть  весь верный до тысяча календарный месяц без комиссия  только хорошо я вы понять по зарплатный_проект информация отмечу и вот э хотеть еще уточнить для вы быть лимит по кредитование вы быть бы интересный рассмотреть  весь хорошо отлично понять вы сейчас сейчас вопрос нет у вы  а  контакт у вы быть если какой тот вопрос быть возникать либо потребоваться оформить услуга сбер звонить большинство из они подключать дистанционно экономить ваш время быть рад помочь вы  весь добрый вы до свидание

# %%
tab_new = pd.read_csv('file.csv', sep=';')
tab_new["topics"] = tab["topics"]

# %%
tab_new["topics"].to_csv("results_lda.csv")
